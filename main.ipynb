# %% [markdown]
# # 8INF919 - Miniprojet
# ## Sujet : Analyse de sentiments avec spark
# ### Gabin Vrillault, Julien Excoffier, Antoine Riom

# %% [markdown]
# ### 2.1.10 - *Pour pouvoir comparer avec les résultats de l’article, entrainer cette fois-ci, un classeur multi-classes en ajoutant la classe « neutre » tout en répétant les étapes précédentes : 2-1-2 à 2-1-9. (6 points)*

# %%
from src.data.load_data import load_data
import pandas as pd

test, train = load_data()

# %% [markdown]
# ### scénario 1: les variables « features » sont constituées uniquement de mots de longueur 1;

# %% [markdown]
# ### scénario 2: les variables « features » sont constituées uniquement de mots de longueur 2;

# %% [markdown]
# ### scénario 3: les variables sont les patterns de mots les plus fréquents. Réutiliser le concept de pattern définit dans l’article,

# %% [markdown]
# ### Scénario 4 : les variables regroupent l’ensemble des sénarios a), b) et c) : les mots, les 2-gram et les patterns (scénario de l’article).

# %% [markdown]
# ### 2.1.11 - *Une fois l’étude (2.1.1 à 2.1.10) est réalisée et démontrée, choisissez un des classeurs (binaire ou ternaire) pour intégrer un filtre de Bloom à la place d’un HashingTF. Vous pouvez réutiliser n’importe quel code trouvé sur le net pour implémenter le filtre de Bloom ! À condition qu’il faut le comprendre et le commenter (1 point).*

# %% [markdown]
# ### 2.1.12 - *Comparer les deux classeurs en question. Est-ce que cette intégration du filtre de Bloom a un impact sur les résultats déjà obtenus avec le classeur que vous avez choisi, en termes d’accuracy, temps d’entrainement et de passage à l’échelle. Tracez les courbes du nouveau classeur basé sur le filtre de Boom. (1 point)*
